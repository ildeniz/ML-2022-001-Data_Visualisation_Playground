# %% [markdown]
# # 0 - Loading libraries

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# # 1 - Line Charts (Trends)

# %%
fifa = pd.read_csv('Data/fifa.csv', index_col="Date", parse_dates=True) # importing the dataset
fifa.shape
# Out:
# (286, 6)

# %% [markdown]
# `index_col="Date"` - When we load the dataset, we want each entry in the first column to denote a different row. To do this, we set the value of `index_col` to the name of the first column ("Date", found in cell A1 of the file when it's opened in Excel).
#
# `parse_dates=True` - This tells the notebook to understand the each row label as a date (as opposed to a number or other text with a different meaning).

# %%
fifa.head()
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %% [markdown]
# ## 1.1 - Matplotlib

# %% [markdown]
# Below is the most basic way of plotting by just using `matplotlib`

# %%
plt.plot(fifa) 
plt.show();

# %%
# Implementation of matplotlib function
import matplotlib.pyplot as plt
import numpy as np
  
fig = plt.figure()
x = np.arange(20) / 50
y = (x + 0.1)*2
  
val1 = [True, False] * 10
val2 = [False, True] * 10
  
plt.errorbar(x, y, 
             xerr = 0.1, 
             xlolims = True, 
             label ='Line 1')
  
y = (x + 0.3)*3
  
plt.errorbar(x + 0.6, y, 
             xerr = 0.1,
             xuplims = val1,
             xlolims = val2,
             label ='Line 2')
  
y = (x + 0.6)*4
plt.errorbar(x + 1.2, y,
             xerr = 0.1, 
             xuplims = True,
             label ='Line 3')
  
plt.legend()
  
fig.suptitle('matplotlib.pyplot.show() Example 1')
plt.show()

# %%
# Implementation of matplotlib function
import matplotlib.pyplot as plt
import numpy as np
  
x = np.linspace(0, 10, 500)
y = np.sin(x**2)+np.cos(x)
  
fig, ax = plt.subplots()
  
ax.plot(x, y, label ='Line 1')
  
ax.plot(x, y - 0.6, label ='Line 2')
  
ax.legend()
  
fig.suptitle('matplotlib.pyplot.show() Example 2')
plt.show()

# %% [markdown]
# ### 1.1 Question
#
# What does `plt.subplots()` exactly do? It takes two arguments; one for figure itself and another to define axes I guess.

# %% [markdown]
# ## 1.2 - Seaborn (sns)

# %% [markdown]
# Another data visualisation library is `Seaborn` (sns), though `sns` is based on `matplotlib`, SNS is much more improved than `matplotlib`.

# %%
# Set the width and height of the figure
plt.figure(figsize=(16,6))

# Add title
plt.title("Fifa Ranking of National Teams in 1993-2018")

# Line chart showing how FIFA rankings evolved over time 
sns.lineplot(data=fifa);

# Add label for horizontal and vertical axes
plt.xlabel("Dates")
plt.ylabel("National Teams' # of Rank by Date")
# Out:
# Text(0, 0.5, "National Teams' # of Rank by Date")

# %% [markdown]
# - Size of the figure is decided through `figsize = (x, y)`. Both arguments are in inches, `x` is width and `y` is height.
#
# - `sns.lineplot` is used to create a line chart. Other examples to visualise data are `sns.barplot` for bar charts and `sns.heatmap` for heatmaps.
#
# - `data =` parameter is used to determine the target data to be visualised and accepts `data_set_name` as argument.

# %% [markdown]
# ## 1.3 - Plotting a subset of the data

# %%
spotify = pd.read_csv('Data/spotify.csv', index_col="Date", parse_dates=True)
spotify#.head()
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN        NaN
# 2017-01-07      13190270        NaN                       NaN        NaN
# 2017-01-08      13099919        NaN                       NaN        NaN
# 2017-01-09      14506351        NaN                       NaN        NaN
# 2017-01-10      14275628        NaN                       NaN        NaN
# ...                  ...        ...                       ...        ...
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# ...

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,6))

# Add title
plt.title("Daily Global Streams of Popular Songs in 2017-2018")

# Line chart showing daily global streams of each song 
sns.lineplot(data=spotify)

# Add label for horizontal and vertical axes
plt.xlabel("Dates")
plt.ylabel("# of views by all songs")
# Out:
# Text(0, 0.5, '# of views by all songs')

# %%
list(spotify.columns)
# Out:
# ['Shape of You',
#  'Despacito',
#  'Something Just Like This',
#  'HUMBLE.',
#  'Unforgettable']

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,6))

# Add title
plt.title("Daily Global Streams of Popular Songs in 2017-2018")

# Line chart showing daily global streams of 'Shape of You'
sns.lineplot(data=spotify['Shape of You'], label="Shape of You")

# Line chart showing daily global streams of 'Despacito'
sns.lineplot(data=spotify['Despacito'], label="Despacito")

# Add label for horizontal and vertical axes
plt.xlabel("Dates")
plt.ylabel("# of views by 'Shape of You' and 'Despacito'")
# Out:
# Text(0, 0.5, "# of views by 'Shape of You' and 'Despacito'")

# %% [markdown]
# Seaborn themes:
# - darkgrid
# - whitegrid
# - dark
# - white
# - ticks

# %%
sns.set_style('darkgrid')

plt.figure(figsize=(14,6))
sns.lineplot(data=spotify);

# %% [markdown]
# # 2 - Bar Charts (Relationship)

# %%
flight_delays = pd.read_csv('Data/flight_delays.csv', index_col="Month")
flight_delays
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# 6      8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# 7      3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# 8      3.193907  2.503899   9.280950  0.653114   5.154422   9.175737
# 9     -1.432732 -1.813800   3.539154 -3.703377   0.851062   0.978460
# 10    -0.580930 -2.993617   3.676787 -5.011516   2.303760   0.082127
# 11     0.772630 -1.916516   1.418299 -3.175414   4.415930  11.164527
# 12     4.149684 -1.846681  13.839290  2.504595   6.685176   9.346221
#
# ...

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Average Arrival Delay for Spirit Airlines (NK) Flights, by Month")

# Bar chart showing average arrival delay for Spirit Airlines flights by month
sns.barplot(x=flight_delays.index, y=flight_delays['NK'], palette = 'jet_r')

# Add label for vertical axis
plt.ylabel("Arrival delay (in minutes)")
# Out:
# Text(0, 0.5, 'Arrival delay (in minutes)')

# %%
# help(sns.barplot)

# %%
ign_scores = pd.read_csv('Data/ign_scores.csv', index_col="Platform")
# ign_scores

# %%
high_score = max(ign_scores.loc['PC',:])
high_score

worst_genre =  min(ign_scores.loc['PlayStation Vita',:])
worst_genre
# Out:
# 5.725

# %%
# Set the width and height of the figure
plt.figure(figsize=(8, 6))
# Bar chart showing average score for racing games by platform
sns.barplot(x=ign_scores['Racing'], y=ign_scores.index)
# Add label for horizontal axis
plt.xlabel("")
# Add label for vertical axis
plt.title("Average Score for Racing Games, by Platform")
# Out:
# Text(0.5, 1.0, 'Average Score for Racing Games, by Platform')

# %% [markdown]
# # 3 - Heatmaps  (Relationship)

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,7))

# Add title
plt.title("Average Arrival Delay for Each Airline, by Month")

# Heatmap showing average arrival delay for each airline by month
sns.heatmap(data=flight_delays, annot=True, square = True, cmap= 'RdPu')

# Add label for horizontal axis
plt.xlabel("Airline")
# Out:
# Text(0.5, 42.0, 'Airline')

# %% [markdown]
# `annot=True` ensures that the values for each cell appear on the chart.

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,10))
# Heatmap showing average game score by platform and genre
sns.heatmap(ign_scores, annot=True); #, square=True);
# Add label for horizontal axis
plt.xlabel("Genre")
# Add label for vertical axis
plt.title("Average Game Score, by Platform and Genre")
# Out:
# Text(0.5, 1.0, 'Average Game Score, by Platform and Genre')

# %% [markdown]
# # 4 - Scatter Plots  (Relationship)

# %% [markdown]
# Scatter plots are good to observe correlation between variables, still one should not neglect that **corellation does not imply causality!!!**.

# %% [markdown]
# `insurance.csv` data set is obtaoned from:
# - https://www.kaggle.com/datasets/mirichoi0218/insurance
# - https://github.com/stedy/Machine-Learning-with-R-datasets

# %%
insurance_data = pd.read_csv('Data/insurance.csv')
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
candy_data = pd.read_csv('Data\candy.csv', index_col='id')
candy_data.head()
# Out:
#    competitorname chocolate fruity caramel peanutyalmondy nougat  \
# id
# 0       100 Grand       Yes     No     Yes             No     No
# 1    3 Musketeers       Yes     No      No             No    Yes
# 2       Air Heads        No    Yes      No             No     No
# 3      Almond Joy       Yes     No      No            Yes     No
# 4       Baby Ruth       Yes     No     Yes            Yes    Yes
#
#    crispedricewafer hard  bar pluribus  sugarpercent  pricepercent  winpercent
# id
# 0               Yes   No  Yes       No         0.732         0.860   66.971725
# 1                No   No  Yes       No         0.604         0.511   67.602936
# 2                No   No   No       No         0.906         0.511   52.341465
# 3                No   No  Yes       No         0.465         0.767   50.347546
# 4                No   No  Yes       No         0.604         0.767   56.914547

# %% [markdown]
# The dataset contains 83 rows, where each corresponds to a different candy bar. There are 13 columns:
# - `competitorname` contains the name of the candy bar.
# - the next 9 columns (from `chocolate` to `pluribus`) describe the candy. For instance, rows with chocolate candies have "Yes" in the 'chocolate' column (and candies without chocolate have "No" in the same column).
# - 'sugarpercent' provides some indication of the amount of sugar, where higher values signify higher sugar content.
# - 'pricepercent' shows the price per unit, relative to the other candies in the dataset.
# - 'winpercent' is calculated from the survey results; higher values indicate that the candy was more popular with survey respondents.

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges']);

# alternative is:
# sns.scatterplot(data = insurance_data, x='bmi', y='charges');

# %%
sns.scatterplot(data = candy_data, x='pricepercent', y='winpercent');

# %% [markdown]
# ## 4.1 - Adding a regression line

# %%
sns.regplot(x=insurance_data['bmi'], y=insurance_data['charges']); #, color = 'green');

# %%
sns.regplot(data = candy_data, x='sugarpercent', y='winpercent');

# %% [markdown]
# Since the regression line has a slightly positive slope, this tells us that there is a slightly positive correlation between `winpercent` and `sugarpercent`. Thus, people have a slight preference for candies containing relatively more sugar.

# %% [markdown]
# ## 4.2 - Colour-coded scatter plots

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'], hue=insurance_data['smoker'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
sns.scatterplot(data = candy_data, x='pricepercent', y='winpercent', hue='chocolate');

# %% [markdown]
# ## 4.3 - Colour code and regression line

# %%
sns.lmplot(x="bmi", y="charges", hue="smoker", data=insurance_data); #, palette='Blues');

# %%
sns.lmplot(data = candy_data, x='pricepercent',y='winpercent', hue='chocolate');

# %% [markdown]
# We'll begin with the regression line for chocolate candies. Since this line has a slightly positive slope, we can say that more expensive chocolate candies tend to be more popular (than relatively cheaper chocolate candies). Likewise, since the regression line for candies without chocolate has a negative slope, we can say that if candies don't contain chocolate, they tend to be more popular when they are cheaper. One important note, however, is that the dataset is quite small -- so we shouldn't invest too much trust in these patterns! To inspire more confidence in the results, we should add more candies to the dataset.

# %% [markdown]
# ## 4.4 - Categorical scatter plot

# %%
sns.swarmplot(x=insurance_data['smoker'],
              y=insurance_data['charges']);
# Out:
# C:\Users\ildeniz\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 67.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.stripplot(x=insurance_data['smoker'],
              y=insurance_data['charges']);

# %%
sns.swarmplot(data = candy_data, x='chocolate', y= 'winpercent');

# %%
sns.stripplot(data = candy_data, x='chocolate', y= 'winpercent');

# %% [markdown]
# # 5 - Histograms (Distribution)

# %%
iris = pd.read_csv('Data/iris.csv')
iris.head()
# Out:
#    Id  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# 0   1                5.1               3.5                1.4
# 1   2                4.9               3.0                1.4
# 2   3                4.7               3.2                1.3
# 3   4                4.6               3.1                1.5
# 4   5                5.0               3.6                1.4
#
#    Petal Width (cm)      Species
# 0               0.2  Iris-setosa
# 1               0.2  Iris-setosa
# 2               0.2  Iris-setosa
# 3               0.2  Iris-setosa
# 4               0.2  Iris-setosa

# %%
cancer = pd.read_csv('Data/cancer.csv', index_col='Id')
cancer.head()
# Out:
#          Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# Id
# 8510426          B         13.540           14.36             87.46
# 8510653          B         13.080           15.71             85.63
# 8510824          B          9.504           12.44             60.34
# 854941           B         13.030           18.42             82.61
# 85713702         B          8.196           16.84             51.71
#
#           Area (mean)  Smoothness (mean)  Compactness (mean)  \
# Id
# 8510426         566.3            0.09779             0.08129
# 8510653         520.0            0.10750             0.12700
# 8510824         273.9            0.10240             0.06492
# 854941          523.8            0.08983             0.03766
# 85713702        201.9            0.08600             0.05943
#
#           Concavity (mean)  Concave points (mean)  Symmetry (mean)  ...  \
# Id                                                                  ...
# ...

# %% [markdown]
# Each tumor has been labeled as either [**benign**](https://en.wikipedia.org/wiki/Benign_tumor) (_noncancerous_) or **malignant** (_cancerous_).
#
# To learn more about how this kind of data is used to create intelligent algorithms to classify tumors in medical settings, **watch the short video [at this link](https://www.youtube.com/watch?v=9Mz84cwVmS0)**.
#
#
# - 1st column ('Diagnosis') classifies tumors as either benign (which appears in the dataset as B) or malignant (M)
# - Reamining 30 columns containing different measurements collected from the images.

# %%
sns.histplot(iris['Petal Length (cm)']);

# %%
sns.histplot(data= cancer, x='Area (mean)');

# %% [markdown]
# ## 5.1 - Colour coded histograms

# %%
# Histograms for each species
sns.histplot(data=iris, x='Petal Length (cm)', hue='Species')

# Add title
plt.title("Histogram of Petal Lengths, by Species");

# %%
sns.histplot(data = cancer, x='Area (mean)', hue= 'Diagnosis');

# %% [markdown]
# # 6 - Density plots (Kernel Density Estimate (KDE)) (Distribution)

# %%
sns.kdeplot(data=iris['Petal Length (cm)'], shade=True);

# %%
sns.kdeplot(data= cancer, x= 'Radius (worst)', shade=True);

# %% [markdown]
# ## 6.1 - 2D KDE plots

# %%
sns.jointplot(x=iris['Petal Length (cm)'], y=iris['Sepal Width (cm)'], kind="kde");

# %%
sns.jointplot(data = iris, x='Petal Length (cm)', y='Sepal Width (cm)', kind="kde", hue='Species');

# %%
sns.jointplot(data = iris, x='Petal Length (cm)', y='Sepal Width (cm)', kind="kde", hue='Species', palette='jet_r');

# %% [markdown]
# ## 6.2 - Colour coded density plots

# %%
# KDE plots for each species
sns.kdeplot(data=iris, x='Petal Length (cm)', hue='Species', shade=True)

# Add title
plt.title("Distribution of Petal Lengths, by Species");

# %%
sns.kdeplot(data = cancer, x= 'Radius (worst)', hue= 'Diagnosis', shade= True);

# %% [markdown]
# # 7 - Histograms and Density plots together
# **WARNING!!** `sns.displot()` is depreciated and will be removed from the package soon -2022.10.11

# %%
skew = iris['Petal Length (cm)'].skew()
sns.distplot(iris['Petal Length (cm)'], label = 'Skew = %.3f' %(skew))
plt.legend(loc='best')
# Out:
# C:\Users\ildeniz\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # A.1 - Seaborn C-map Options

# %%
# sns.palplot(sns.color_palette("Blue"));

# %%
# To get these, I ran a wrong option and copy and pasted them out of the error message.
cmaps = 'Accent, Accent_r, Blues, Blues_r, BrBG, BrBG_r, BuGn, BuGn_r, BuPu, BuPu_r, CMRmap, CMRmap_r, Dark2, Dark2_r, GnBu, GnBu_r, Greens, Greens_r, Greys, Greys_r, OrRd, OrRd_r, Oranges, Oranges_r, PRGn, PRGn_r, Paired, Paired_r, Pastel1, Pastel1_r, Pastel2, Pastel2_r, PiYG, PiYG_r, PuBu, PuBuGn, PuBuGn_r, PuBu_r, PuOr, PuOr_r, PuRd, PuRd_r, Purples, Purples_r, RdBu, RdBu_r, RdGy, RdGy_r, RdPu, RdPu_r, RdYlBu, RdYlBu_r, RdYlGn, RdYlGn_r, Reds, Reds_r, Set1, Set1_r, Set2, Set2_r, Set3, Set3_r, Spectral, Spectral_r, Wistia, Wistia_r, YlGn, YlGnBu, YlGnBu_r, YlGn_r, YlOrBr, YlOrBr_r, YlOrRd, YlOrRd_r, afmhot, afmhot_r, autumn, autumn_r, binary, binary_r, bone, bone_r, brg, brg_r, bwr, bwr_r, cividis, cividis_r, cool, cool_r, coolwarm, coolwarm_r, copper, copper_r, cubehelix, cubehelix_r, flag, flag_r, gist_earth, gist_earth_r, gist_gray, gist_gray_r, gist_heat, gist_heat_r, gist_ncar, gist_ncar_r, gist_rainbow, gist_rainbow_r, gist_stern, gist_stern_r, gist_yarg, gist_yarg_r, gnuplot, gnuplot2, gnuplot2_r, gnuplot_r, gray, gray_r, hot, hot_r, hsv, hsv_r, icefire, icefire_r, inferno, inferno_r, jet, jet_r, magma, magma_r, mako, mako_r, nipy_spectral, nipy_spectral_r, ocean, ocean_r, pink, pink_r, plasma, plasma_r, prism, prism_r, rainbow, rainbow_r, rocket, rocket_r, seismic, seismic_r, spring, spring_r, summer, summer_r, tab10, tab10_r, tab20, tab20_r, tab20b, tab20b_r, tab20c, tab20c_r, terrain, terrain_r, viridis, viridis_r, vlag, vlag_r, winter, winter_r'

cmap_s = cmaps.split(', ')

# %%
for c in cmap_s:
    print(c)
    try:
        sns.palplot(sns.color_palette(c, 25));
        plt.show()
    except:
        print('               ¯\_(ツ)_/¯')
# Out:
# Accent
# Accent_r
# Blues
# Blues_r
# BrBG
# BrBG_r
# BuGn
# BuGn_r
# BuPu
# BuPu_r
# CMRmap
# CMRmap_r
# Dark2
# Dark2_r
# GnBu
# GnBu_r
# Greens
# Greens_r
# Greys
# Greys_r
# OrRd
# OrRd_r
# Oranges
# Oranges_r
# PRGn
# PRGn_r
# Paired
# Paired_r
# Pastel1
# Pastel1_r
# Pastel2
# Pastel2_r
# PiYG
# PiYG_r
# PuBu
# PuBuGn
# PuBuGn_r
# PuBu_r
# PuOr
# PuOr_r
# PuRd
# PuRd_r
# Purples
# Purples_r
# RdBu
# RdBu_r
# RdGy
# RdGy_r
# RdPu
# RdPu_r
# RdYlBu
# RdYlBu_r
# RdYlGn
# RdYlGn_r
# Reds
# Reds_r
# Set1
# Set1_r
# Set2
# Set2_r
# Set3
# Set3_r
# Spectral
# Spectral_r
# Wistia
# Wistia_r
# YlGn
# YlGnBu
# YlGnBu_r
# YlGn_r
# YlOrBr
# YlOrBr_r
# YlOrRd
# YlOrRd_r
# afmhot
# afmhot_r
# autumn
# autumn_r
# binary
# binary_r
# bone
# bone_r
# brg
# brg_r
# bwr
# bwr_r
# cividis
# cividis_r
# cool
# cool_r
# coolwarm
# coolwarm_r
# copper
# copper_r
# cubehelix
# cubehelix_r
# flag
# flag_r
# gist_earth
# gist_earth_r
# gist_gray
# gist_gray_r
# gist_heat
# gist_heat_r
# gist_ncar
# ...
